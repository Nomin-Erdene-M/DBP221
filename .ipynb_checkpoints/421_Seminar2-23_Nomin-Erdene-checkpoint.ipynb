# %%
# 1
def palindrom(a):
    if a == a[::-1]:
        return('Palindrome')
    else:
        return('Not palindrome')
print(palindrom('hadgalagdah'))
# Out:
# Palindrome

# %%
# 2
# def counter(list1):
def upperlower(list1):
    a=' '.join(list1)
    upper = 0
    lower = 0
    for i in range(len(a)):
        if(a[i]>='a' and a[i]<='z'):
            lower+=1
        elif(a[i]>='A' and a[i]<='Z'):
            upper+=1  
    print('Жижгээр бичигдсэн=' ,lower)
    print('Томоор бичигдсэн=' ,upper)     
string = 'My name is Nomin-Erdene'
upperlower(string)
# Out:
# Жижгээр бичигдсэн= 16
# Томоор бичигдсэн= 3

# %%
# 3
def urjver(numlist):
    y=1
    k=0
    while len(numlist)>k:
        y = y*numlist[k]
        k += 1
    return(y)
a = [1,2,3,4,5]
print(urjver(a))
# Out:
# 120

# %%
# 4
def factorial(number):
    if number < 0:
        return('Surug toonii factorial oldohgui')
    elif number == 0:
        return('1')
    else:
        bakteral=1
        for i in range(1, number+1):
            bakteral = bakteral * i
        return(bakteral)
print(factorial(1))
# Out:
# 1

# %%
# 5
def urvuu(list1):
    list1.reverse()
    return(list1)
letters = ['a', 'b', 'c', 'd','e']
print(urvuu(letters))
# Out:
# ['e', 'd', 'c', 'b', 'a']

# %%
# 6
def niilber(numlist):
    sum = 0
    k=0
    while len(numlist)>k:
        sum += numlist[k]
        k += 1
    return(sum)
a = [1,2,3,4,5]
print(niilber(a))
# Out:
# 15

# %%
# 7
def overlap(list1):
    list2 = []
    [list2.append(i) for i in list1 if i not in list2]
    return(list2)
list1 = [1,3,2,5,1,3,4,5,1,2]
print(overlap(list1))
# Out:
# [1, 3, 2, 5, 4]

# %%
# 8
def maximum(a,b,c):
    if a>b and a>c:
        return(a)
    elif b>a and b>c:
        return(b)
    else:
        return(c)
print(maximum(3,6,5))
# Out:
# 6
